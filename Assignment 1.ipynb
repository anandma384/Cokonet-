# %% [markdown]
# Demo

# %% [markdown]
# # Anand M A

# %% [markdown]
# ## Trivandrum

# %% [markdown]
#   ![Signature.jpg](attachment:77021e89-fe50-49b1-a4cc-32badad37ec8.jpg)

# %% [markdown]
# ![Signature.jpg](attachment:edf06ae1-026f-448b-8f7d-6c10c6e43721.jpg)

# %% [markdown]
# Testing functionality

# %%
1+2
# Out:
# 3

# %%
10/2
# Out:
# 5.0

# %% [markdown]
# - Test Line 1
# - Yest Line 2
